# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2
import torch
import sys
import random
from Networks import (
    DummySteerModel,
    SteerNN
)
import pickle

sys.path.append('./3_cameras/steerings/')
from steer001 import *
from steer002 import *
from steer003 import *
from steer004 import *
from steer005 import *
from steer006 import *
from steer007 import *
from steer008 import *
from steer009 import *
from steer010 import *
from steer011 import *
from steer012 import *

# %%
#put the steering data all in an array
steering001 = np.expand_dims(steering001,0)
steering002 = np.expand_dims(steering002,0)
steering003 = np.expand_dims(steering003,0)
steering004 = np.expand_dims(steering004,0)
steering005 = np.expand_dims(steering005,0)
steering006 = np.expand_dims(steering006,0)
steering007 = np.expand_dims(steering007,0)
steering008 = np.expand_dims(steering008,0)
steering009 = np.expand_dims(steering009,0)
steering010 = np.expand_dims(steering010,0)
steering011 = np.expand_dims(steering011,0)
steering012 = np.expand_dims(steering012,0)
print(steering001.shape)
steering_data = np.append(steering001, steering002, axis=0)
steering_data = np.append(steering_data, steering003, axis=0)
steering_data = np.append(steering_data, steering004, axis=0)
steering_data = np.append(steering_data, steering005, axis=0)
steering_data = np.append(steering_data, steering006, axis=0)
steering_data = np.append(steering_data, steering007, axis=0)
steering_data = np.append(steering_data, steering008, axis=0)
steering_data = np.append(steering_data, steering009, axis=0)
steering_data = np.append(steering_data, steering010, axis=0)
steering_data = np.append(steering_data, steering011, axis=0)
steering_data = np.append(steering_data, steering012, axis=0)
steering_data = steering_data *100
print(steering_data.shape)
# Out:
# (1, 110)
# (12, 110)

# %%
#put the images and steeings into dicts
list_of_image_data = []
for j in range(1,13):
    path_to_images_middle = './3_cameras/Dataset%03d_middle/' %j
    path_to_images_left = './3_cameras/Dataset%03d_left/' %j
    path_to_images_right = './3_cameras/Dataset%03d_right/' %j
    image_paths_middle = os.listdir(path_to_images_middle)
    image_paths_left = os.listdir(path_to_images_left)
    image_paths_right = os.listdir(path_to_images_right)
    image_paths_middle.sort()
    image_paths_left.sort()
    image_paths_right.sort()
    #print(image_paths_left)     #number of images in each dataset:110
    print(path_to_images_middle)
    
    i = 0
    for im in image_paths_middle:
        image = np.empty([3,600,800])
        image_middle = np.transpose(cv2.imread(path_to_images_middle+im)[:,:,:1], (2, 0, 1))
        image_left = np.transpose(cv2.imread(path_to_images_left+im)[:,:,:1], (2, 0, 1))
        image_right = np.transpose(cv2.imread(path_to_images_right+im)[:,:,:1], (2, 0, 1))
        #img = (cv2.imread(path_to_images+im)[:,:,:3])/255
        #cv2.imshow("image", img)
        #cv2.waitKey(10) 
        image[0,:,:] = image_left
        image[1,:,:] = image_middle
        image[2,:,:] = image_right
        image = torch.from_numpy(image)
        image = image.float()      #convert from int to float
        imdict = {
            'image': image,
            'steer':steering_data[j-1][i]
        }
        list_of_image_data.append(imdict)
        i+=1
# Out:
# ./3_cameras/Dataset001_middle/
# ./3_cameras/Dataset002_middle/
# ./3_cameras/Dataset003_middle/
# ./3_cameras/Dataset004_middle/
# ./3_cameras/Dataset005_middle/
# ./3_cameras/Dataset006_middle/
# ./3_cameras/Dataset007_middle/
# ./3_cameras/Dataset008_middle/
# ./3_cameras/Dataset009_middle/
# ./3_cameras/Dataset010_middle/
# ./3_cameras/Dataset011_middle/
# ./3_cameras/Dataset012_middle/

# %%
#show an image and its corresponding steering
print(len(list_of_image_data))
print(list_of_image_data[0]["image"].shape)    #size of image: torch.Size([1, 600, 800])
print(list_of_image_data[0]["steer"])

#visualize the images
image = (list_of_image_data[0]["image"].clone()/255 ).view(3, 600, 800)  
image = np.transpose(image,(1,2,0))
image_left = image[:,:,0]
image_middle = image[:,:,1]
image_right = image[:,:,2]


plt.subplot(2, 2, 1)
plt.imshow(image_left, cmap='gray')
plt.axis('off')
plt.title("image_left")
plt.subplot(2, 2, 2)
plt.imshow(image_middle, cmap='gray')
plt.axis('off')
plt.title("image_middle")
plt.subplot(2, 2, 3)
plt.imshow(image_right, cmap='gray')
plt.axis('off')
plt.title("image_right")
plt.subplot(2, 2, 4)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title("image_mixed")
plt.show()
# Out:
# 1320
# torch.Size([3, 600, 800])
# -1.006747

# %%
def num_in_range(lst,small,large):
    length = len(lst)
    num = 0
    for i in range(length):
        if (lst[i]['steer']>= small) & (lst[i]['steer']<= large):
            num += 1
    return num

# %%
#list_of_image_data.sort(key=lambda k: (k.get('steer', 0))) #sort the list according to 'steer'
print("turning left", num_in_range(list_of_image_data,-100,-4))
print("going straight", num_in_range(list_of_image_data,-4,4))
print("turning right", num_in_range(list_of_image_data,4,100))
# Out:
# turning left 388
# going straight 546
# turning right 386

# %%
random.shuffle(list_of_image_data)   #shuffle the list randomly
print(list_of_image_data[0]['steer'])
train_dataset = list_of_image_data[:1100]
val_dataset = list_of_image_data[1100:]
print("length of training dataset", len(train_dataset))
print("length of validation dataset", len(val_dataset))
print(train_dataset[0]['steer'])
print(val_dataset[0]['steer'])
# Out:
# -11.4331529
# length of training dataset 1100
# length of validation dataset 220
# -11.4331529
# 2.170034

# %%
hparams = {
    "learning_rate": 0.8e-3,
    "batch_size": 50,
}

# %%
#test with one image before training
steer_model = SteerNN(hparams)
#print(list_of_image_data[0]['image'])
steer_model(list_of_image_data[0]['image'])
# Out:
# tensor([[1.6531]], grad_fn=<AddmmBackward>)

# %%
import pytorch_lightning as pl

steer_model = SteerNN(hparams, train_dataset, val_dataset)


trainer = pl.Trainer(
    weights_summary=None,
    max_epochs=100,
    progress_bar_refresh_rate=1, # to prevent notebook crashes in Google Colab environments    
)

trainer.fit(steer_model)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Validation sanity check: 0it [00:00, ?it/s]
# /home/melina/anaconda3/envs/py37/lib/python3.7/site-packages/pytorch_lightning/trainer/data_loading.py:106: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# validation loss tensor(127.9030, dtype=torch.float64)
# validation loss tensor(123.7964, dtype=torch.float64)
# /home/melina/anaconda3/envs/py37/lib/python3.7/site-packages/pytorch_lightning/trainer/data_loading.py:106: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# /home/melina/anaconda3/envs/py37/lib/python3.7/site-packages/pytorch_lightning/trainer/data_loading.py:327: UserWarning: The number of training samples (22) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   f"The number of training samples ({self.num_training_batches}) is smaller than the logging interval"
# Training: -1it [00:00, ?it/s]
# training loss tensor(142.0312, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(7461663.8103, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(118585.6123, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(100056.2628, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(129607.7376, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(103172.8219, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(69362.0747, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(41090.2205, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(28736.4083, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(23279.3267, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(13683.5353, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(7786.5549, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2856.8213, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(752.2086, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(158.5397, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1366.5655, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3599.4577, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(6180.2063, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5864.5058, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5802.9796, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3494.3132, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1804.1455, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(483.7783, dtype=torch.float64)
# validation loss tensor(652.8553, dtype=torch.float64)
# validation loss tensor(459.4305, dtype=torch.float64)
# validation loss tensor(632.0690, dtype=torch.float64)
# validation loss tensor(555.9457, dtype=torch.float64)
# training loss tensor(479.6760, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(152.4279, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(865.7830, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1973.3460, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2217.9581, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1856.0272, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1254.4115, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(441.0768, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(108.4598, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(90.9523, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(359.0329, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(708.2099, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(864.5845, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(883.5209, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(627.0903, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(308.0115, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(209.3455, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(63.9504, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(166.0535, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(275.5907, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(387.2825, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(517.3931, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(305.0481, dtype=torch.float64)
# validation loss tensor(257.9890, dtype=torch.float64)
# validation loss tensor(278.0677, dtype=torch.float64)
# validation loss tensor(222.5386, dtype=torch.float64)
# validation loss tensor(257.7591, dtype=torch.float64)
# training loss tensor(307.0074, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(187.2987, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(68.5781, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(47.8978, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(105.2104, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(168.6395, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(188.8871, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(217.4185, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(135.4670, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(83.4447, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(50.5953, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(41.4460, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(56.6398, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(115.8263, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(105.1712, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(80.1457, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(66.4039, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(44.7156, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(26.4296, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(34.6326, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(47.3313, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(74.1688, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(51.9244, dtype=torch.float64)
# validation loss tensor(59.3412, dtype=torch.float64)
# validation loss tensor(54.7519, dtype=torch.float64)
# validation loss tensor(66.2812, dtype=torch.float64)
# validation loss tensor(55.0246, dtype=torch.float64)
# training loss tensor(56.9982, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(36.8573, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(17.0608, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(36.9733, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(17.7585, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(37.0264, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(41.1023, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(28.2578, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(40.6149, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(23.2285, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(13.4868, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(13.5726, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(26.6291, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(29.3775, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(40.2218, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(22.3444, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(16.3642, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(16.3946, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(15.2069, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(11.3958, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(15.1052, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(21.8846, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(11.6362, dtype=torch.float64)
# validation loss tensor(14.2576, dtype=torch.float64)
# validation loss tensor(17.6517, dtype=torch.float64)
# validation loss tensor(8.7377, dtype=torch.float64)
# validation loss tensor(9.2793, dtype=torch.float64)
# training loss tensor(24.3137, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(11.9631, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(18.1540, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(15.6177, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(17.3732, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(15.6149, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(14.7931, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(10.7723, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(11.9040, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(9.3738, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(7.9751, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(16.0007, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(8.3769, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(8.6818, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(6.8691, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(10.5512, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(8.9558, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(8.8998, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(10.1031, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(6.8538, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(10.1594, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.6795, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(6.0741, dtype=torch.float64)
# validation loss tensor(8.2633, dtype=torch.float64)
# validation loss tensor(11.2362, dtype=torch.float64)
# validation loss tensor(5.8859, dtype=torch.float64)
# validation loss tensor(4.4058, dtype=torch.float64)
# training loss tensor(9.3782, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(8.2033, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(9.9992, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(6.0154, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(10.2991, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(8.3824, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(8.0499, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(6.3153, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.4141, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(6.4313, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(7.1109, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(10.4238, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(9.6140, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(9.8103, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(6.0640, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(9.1749, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(9.8446, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(7.2718, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.5079, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(9.3408, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.8283, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(10.4164, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(5.3265, dtype=torch.float64)
# validation loss tensor(8.6167, dtype=torch.float64)
# validation loss tensor(10.8307, dtype=torch.float64)
# validation loss tensor(5.9177, dtype=torch.float64)
# validation loss tensor(5.0988, dtype=torch.float64)
# training loss tensor(6.1221, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.9563, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.4403, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(6.0584, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(6.3742, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(7.5508, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(6.0673, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.4718, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(9.1463, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(6.1736, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(9.8170, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.4659, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.2484, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(7.5009, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.6811, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.0670, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(8.2239, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(9.7093, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(9.2640, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(8.3261, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.5362, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.7901, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(5.8574, dtype=torch.float64)
# validation loss tensor(7.2086, dtype=torch.float64)
# validation loss tensor(9.6745, dtype=torch.float64)
# validation loss tensor(4.3600, dtype=torch.float64)
# validation loss tensor(3.5927, dtype=torch.float64)
# training loss tensor(6.7678, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.8962, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.1624, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.6042, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.2676, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.8289, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.8123, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.0007, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(6.3249, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.8863, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(6.8969, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.1025, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(6.1435, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.4097, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.3371, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.2604, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(7.2705, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(7.6910, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(6.7103, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.3343, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.8631, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.2214, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(5.3051, dtype=torch.float64)
# validation loss tensor(7.6607, dtype=torch.float64)
# validation loss tensor(9.3696, dtype=torch.float64)
# validation loss tensor(4.8495, dtype=torch.float64)
# validation loss tensor(4.1879, dtype=torch.float64)
# training loss tensor(6.9024, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.5393, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.4344, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.3496, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.1894, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(6.1867, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.0661, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.2265, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.3531, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.9565, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(7.0567, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(7.9724, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.3775, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.6332, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.9419, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.4287, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(8.2399, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.1561, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.2104, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(7.2329, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.5472, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.6948, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(5.1769, dtype=torch.float64)
# validation loss tensor(7.0380, dtype=torch.float64)
# validation loss tensor(9.3338, dtype=torch.float64)
# validation loss tensor(4.6746, dtype=torch.float64)
# validation loss tensor(3.5429, dtype=torch.float64)
# training loss tensor(4.3464, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.8886, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.7684, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.1438, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.9254, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.5654, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.7010, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.9466, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.7349, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.3870, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.2776, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.2704, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.7941, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.5923, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.7099, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.6004, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.2677, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.0652, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.8059, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.8493, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.6135, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.5304, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(5.1802, dtype=torch.float64)
# validation loss tensor(7.1979, dtype=torch.float64)
# validation loss tensor(8.5848, dtype=torch.float64)
# validation loss tensor(4.2628, dtype=torch.float64)
# validation loss tensor(3.9766, dtype=torch.float64)
# training loss tensor(3.2737, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.6838, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.8961, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.5807, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.1143, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.0696, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.0214, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.7477, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.4958, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.3726, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.2846, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.4638, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.9508, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.7455, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.0168, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.8982, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.5755, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.6927, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.4486, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.8257, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.0900, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.2660, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(5.4283, dtype=torch.float64)
# validation loss tensor(6.4498, dtype=torch.float64)
# validation loss tensor(8.1027, dtype=torch.float64)
# validation loss tensor(3.8821, dtype=torch.float64)
# validation loss tensor(3.5489, dtype=torch.float64)
# training loss tensor(1.9848, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.8478, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.1161, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.2898, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.7091, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.4373, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.2240, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.1187, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.7310, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.0092, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.6754, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.5481, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.2544, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.8311, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.5076, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.9049, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.1389, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.2482, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.0121, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.9669, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.9780, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.5764, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(5.1734, dtype=torch.float64)
# validation loss tensor(6.7245, dtype=torch.float64)
# validation loss tensor(8.4679, dtype=torch.float64)
# validation loss tensor(4.0614, dtype=torch.float64)
# validation loss tensor(3.3888, dtype=torch.float64)
# training loss tensor(1.8242, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.6431, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.1715, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.8872, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.3477, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.6104, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.0440, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.9547, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.4893, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.8281, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.6509, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.1176, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.4100, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.5806, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.3976, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.0813, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.4716, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.5629, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.5948, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.2524, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.9822, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.4100, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(5.2512, dtype=torch.float64)
# validation loss tensor(7.7247, dtype=torch.float64)
# validation loss tensor(8.4938, dtype=torch.float64)
# validation loss tensor(4.4633, dtype=torch.float64)
# validation loss tensor(3.9992, dtype=torch.float64)
# training loss tensor(2.4903, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.9712, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.8694, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.9893, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.9420, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.0657, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.1925, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.2230, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.7499, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.8421, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.9783, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.2944, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.1799, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(5.7346, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.5648, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.3021, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.0424, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.6385, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.6100, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.2936, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.1556, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.3938, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(5.2263, dtype=torch.float64)
# validation loss tensor(6.8581, dtype=torch.float64)
# validation loss tensor(7.7618, dtype=torch.float64)
# validation loss tensor(4.0655, dtype=torch.float64)
# validation loss tensor(3.7403, dtype=torch.float64)
# training loss tensor(3.0926, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.8460, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.3540, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.9122, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.3065, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.1006, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.1781, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.4950, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.8201, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.0413, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.1822, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.2085, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.6535, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.7957, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.5762, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.3769, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.5745, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.5850, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.0828, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.0491, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.4895, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.1725, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(5.5387, dtype=torch.float64)
# validation loss tensor(6.7171, dtype=torch.float64)
# validation loss tensor(7.9020, dtype=torch.float64)
# validation loss tensor(3.7569, dtype=torch.float64)
# validation loss tensor(3.5791, dtype=torch.float64)
# training loss tensor(1.2950, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8375, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.3873, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.4912, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.2667, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.1802, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.0277, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8699, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.3715, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.4621, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.4101, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.0881, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.9628, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.6463, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.3067, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.3112, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.4058, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.7201, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.1531, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.5077, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.7477, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.2927, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(5.2543, dtype=torch.float64)
# validation loss tensor(6.7976, dtype=torch.float64)
# validation loss tensor(8.2486, dtype=torch.float64)
# validation loss tensor(4.0301, dtype=torch.float64)
# validation loss tensor(3.3432, dtype=torch.float64)
# training loss tensor(0.9045, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.1239, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.9601, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.2838, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.4069, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.2071, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.2210, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.9026, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.3581, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.3577, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.6074, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.2989, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.0057, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.5661, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.3036, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.2641, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.6599, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.2422, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.9426, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.7102, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8717, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(4.3166, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(6.2367, dtype=torch.float64)
# validation loss tensor(7.0240, dtype=torch.float64)
# validation loss tensor(7.4012, dtype=torch.float64)
# validation loss tensor(3.7988, dtype=torch.float64)
# validation loss tensor(4.1278, dtype=torch.float64)
# training loss tensor(3.0164, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.0877, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.7245, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.0459, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.3996, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.0821, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.5774, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.6398, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.7097, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.8654, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.1309, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.4080, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.2540, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.9252, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.1275, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.6156, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.0270, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8981, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.9900, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.3038, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.1085, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.9493, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(5.3838, dtype=torch.float64)
# validation loss tensor(7.0007, dtype=torch.float64)
# validation loss tensor(8.0829, dtype=torch.float64)
# validation loss tensor(4.0204, dtype=torch.float64)
# validation loss tensor(3.5679, dtype=torch.float64)
# training loss tensor(0.5547, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.7474, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8822, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.7311, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.9618, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.4427, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.0700, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.3165, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.1449, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.5515, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.2662, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.0192, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.1259, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8898, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.1196, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.9221, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.0858, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.4086, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.4872, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.8030, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8841, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.9218, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(5.3156, dtype=torch.float64)
# validation loss tensor(6.9091, dtype=torch.float64)
# validation loss tensor(7.8797, dtype=torch.float64)
# validation loss tensor(3.6367, dtype=torch.float64)
# validation loss tensor(3.4018, dtype=torch.float64)
# training loss tensor(1.2529, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.9114, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.0834, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.4693, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8491, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6103, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.9148, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6748, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.4124, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.0129, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.0974, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.9280, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.5461, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6569, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.9587, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.7553, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.2768, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.9246, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(3.3865, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6238, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.5994, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.9044, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(5.2745, dtype=torch.float64)
# validation loss tensor(7.1031, dtype=torch.float64)
# validation loss tensor(7.9189, dtype=torch.float64)
# validation loss tensor(3.7327, dtype=torch.float64)
# validation loss tensor(3.6709, dtype=torch.float64)
# training loss tensor(1.3575, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.1175, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.1942, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8237, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.9408, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.7325, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.4541, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8586, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.6760, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.4828, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.9177, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.5685, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.7614, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6923, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.9587, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6927, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.5145, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6543, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.5212, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6770, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.2251, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.7456, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(5.5849, dtype=torch.float64)
# validation loss tensor(7.0658, dtype=torch.float64)
# validation loss tensor(7.3583, dtype=torch.float64)
# validation loss tensor(3.4833, dtype=torch.float64)
# validation loss tensor(3.8120, dtype=torch.float64)
# training loss tensor(1.5316, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.5759, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.4566, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.3739, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8015, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.9163, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.7751, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6142, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.2069, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.1543, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.7622, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.9820, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8856, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.8069, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.5908, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.5373, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.7944, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8910, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6416, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.9900, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.1166, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.7193, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(5.9711, dtype=torch.float64)
# validation loss tensor(7.1967, dtype=torch.float64)
# validation loss tensor(7.6679, dtype=torch.float64)
# validation loss tensor(3.7448, dtype=torch.float64)
# validation loss tensor(3.7775, dtype=torch.float64)
# training loss tensor(1.0068, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.5904, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6142, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.7565, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.1180, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8052, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.5128, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(2.0891, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.5815, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.2012, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.4766, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.9211, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.5945, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.4126, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.4562, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8067, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.5524, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8678, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.0503, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8087, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6243, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.1767, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(5.8450, dtype=torch.float64)
# validation loss tensor(7.0160, dtype=torch.float64)
# validation loss tensor(7.7929, dtype=torch.float64)
# validation loss tensor(3.7873, dtype=torch.float64)
# validation loss tensor(3.4597, dtype=torch.float64)
# training loss tensor(1.7796, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.5572, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.1029, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6204, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.9640, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.0677, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.1883, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.5089, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.4822, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.9185, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.5818, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6254, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.7872, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.5851, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6364, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.4900, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.3506, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.0428, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.5852, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.3204, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8433, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.0945, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(5.2660, dtype=torch.float64)
# validation loss tensor(7.4637, dtype=torch.float64)
# validation loss tensor(7.7659, dtype=torch.float64)
# validation loss tensor(3.7935, dtype=torch.float64)
# validation loss tensor(3.6028, dtype=torch.float64)
# training loss tensor(0.5350, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6378, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.4068, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.7494, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.7327, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.7390, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6142, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.8828, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.3769, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.7643, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.0237, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8054, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.4901, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6964, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6038, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.7795, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.1914, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.4081, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8578, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.7835, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.3901, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.4781, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(5.3440, dtype=torch.float64)
# validation loss tensor(7.0883, dtype=torch.float64)
# validation loss tensor(7.9409, dtype=torch.float64)
# validation loss tensor(3.8537, dtype=torch.float64)
# validation loss tensor(3.5754, dtype=torch.float64)
# training loss tensor(0.5098, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.5612, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.4380, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6536, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.3994, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.6049, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.2772, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.2996, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.4496, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(1.3246, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6306, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.7063, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.4798, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.3478, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6891, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.5554, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.4264, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.8526, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.7103, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.3764, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.5028, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.6287, dtype=torch.float64, grad_fn=<MseLossBackward>)
# Validating: 0it [00:00, ?it/s]
# validation loss tensor(5.2708, dtype=torch.float64)
# validation loss tensor(7.1575, dtype=torch.float64)
# validation loss tensor(7.9759, dtype=torch.float64)
# validation loss tensor(3.8272, dtype=torch.float64)
# validation loss tensor(3.2768, dtype=torch.float64)
# training loss tensor(0.3704, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.4742, dtype=torch.float64, grad_fn=<MseLossBackward>)
# training loss tensor(0.3565, dtype=torch.float64, grad_fn=<MseLossBackward>)
# /home/melina/anaconda3/envs/py37/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:1051: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")

# %%
#test with one image after training
steer_test = steer_model(list_of_image_data[1000]['image'])/100
steer_test = float(steer_test)
print(steer_test)
print(list_of_image_data[1000]['steer']/100)
# Out:
# 0.004146834835410118
# 0.00820596

# %%
PATH = 'models/2extra_camera.p'
torch.save(steer_model.state_dict(),PATH)

# %%
PATH = 'models/2extra_camera.p'
steer_model2 = SteerNN(None)
steer_model2.load_state_dict(torch.load(PATH))
print(steer_model2(list_of_image_data[1200]['image'])/100)
print(list_of_image_data[1200]['steer']/100)
# Out:
# tensor([[0.0843]], grad_fn=<DivBackward0>)
# 0.06760752
